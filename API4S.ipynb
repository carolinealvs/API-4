# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinealvs/API-4/blob/main/API4S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
caminho_in = '/content/drive/My Drive/Data/'
caminho_out = '/content/drive/My Drive/Data/'

# %%
file1 = caminho_in + '2023Atracacao.csv'
with open(file1, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: ﻿IDAtracacao;CDTUP;IDBerco;Berço;Porto Atracação;Coordenadas;Apelido Instalação Portuária;Complexo Portuário;Tipo da Autoridade Portuária;Data Atracação;Data Chegada;Data Desatracação;Data Início Operação;Data Término Operação;Ano;Mes;Tipo de Operação;Tipo de Navegação da Atracação;Nacionalidade do Armador;FlagMCOperacaoAtracacao;Terminal;Município;UF;SGUF;Região Geográfica;Região Hidrográfica;Instalação Portuária em Rio;Nº da Capitania;Nº do IMO
#
# Linha 2: 1383028;BRBEL;BEL0004;4;Belém;-48.497777,-1.445278;;Vila do Conde - Belém;Porto Organizado;06/10/2023 15:50:00;06/10/2023 12:00:00;08/10/2023 12:00:00;06/10/2023 16:00:00;08/10/2023 11:00:00;2023;out;Marinha;Cabotagem;0;1;Cais Público 1 - Belém;Belém;Pará;PA;Norte;  Tocantins-Araguaia;Sim;;
#
# Linha 3: 1330420;BRSC013;BRSC0130001;Cais 1;Barra do Rio Terminal Portuário;-48.6721,-26.8833;;Itajaí;Terminal Autorizado;14/04/2023 14:35:00;14/04/2023 14:30:00;17/04/2023 06:02:00;;;2023;abr;Marinha;Apoio Marítimo;0;1;Barra do Rio Terminal Portuário;Itajaí;Santa Catarina;SC;Sul; Atlântico Sul;Sim;;
#
# Linha 4: 1371953;BRBEL;BEL0004;4;Belém;-48.497777,-1.445278;;Vila do Conde - Belém;Porto Organizado;05/08/2023 13:55:00;05/08/2023 11:00:00;10/08/2023 05:30:00;05/08/2023 15:00:00;09/08/2023 17:00:00;2023;ago;Marinha;Longo Curso;0;1;Cais Público 1 - Belém;Belém;Pará;PA;Norte;  Tocantins-Araguaia;Sim;;
#
# Linha 5: 1330416;BRSC013;BRSC0130001;Cais 1;Barra do Rio Terminal Portuário;-48.6721,-26.8833;;Itajaí;Terminal Autorizado;07/04/2023 09:25:00;07/04/2023 09:20:00;08/04/2023 09:50:00;;;2023;abr;Marinha;Apoio Marítimo;0;1;Barra do Rio Terminal Portuário;Itajaí;Santa Catarina;SC;Sul; Atlântico Sul;Sim;;

# %%
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93908 entries, 0 to 93907
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDAtracacao                     93908 non-null  int64
#  1   CDTUP                           93908 non-null  object
#  2   IDBerco                         93784 non-null  object
#  3   Berço                           93784 non-null  object
#  4   Porto Atracação                 93784 non-null  object
#  5   Coordenadas                     93784 non-null  object
#  6   Apelido Instalação Portuária    30353 non-null  object
#  7   Complexo Portuário              93908 non-null  object
#  8   Tipo da Autoridade Portuária    93908 non-null  object
#  9   Data Atracação                  93784 non-null  object
#  10  Data Chegada                    93784 non-null  object
#  11  Data Desatracação               93908 non-null  object
#  12  Data Início Operação            88941 non-null  object
#  13  Data Término Operação           88961 non-null  object
#  14  Ano                             93908 non-null  int64
#  15  Mes                             93908 non-null  object
#  16  Tipo de Operação                93784 non-null  object
#  17  Tipo de Navegação da Atracação  93784 non-null  object
#  18  Nacionalidade do Armador        93784 non-null  float64
#  19  FlagMCOperacaoAtracacao         93908 non-null  int64
#  20  Terminal                        93784 non-null  object
#  21  Município                       93784 non-null  object
#  22  UF                              93784 non-null  object
#  23  SGUF                            93784 non-null  object
#  24  Região Geográfica               93784 non-null  object
#  25  Região Hidrográfica             49415 non-null  object
#  26  Instalação Portuária em Rio     93908 non-null  object
#  27  Nº da Capitania                 58934 non-null  object
#  28  Nº do IMO                       48049 non-null  float64
# dtypes: float64(2), int64(3), object(24)
# memory usage: 20.8+ MB

# %%
file2 = caminho_in + '2024Atracacao.csv'
with open(file2, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: ﻿IDAtracacao;CDTUP;IDBerco;Berço;Porto Atracação;Coordenadas;Apelido Instalação Portuária;Complexo Portuário;Tipo da Autoridade Portuária;Data Atracação;Data Chegada;Data Desatracação;Data Início Operação;Data Término Operação;Ano;Mes;Tipo de Operação;Tipo de Navegação da Atracação;Nacionalidade do Armador;FlagMCOperacaoAtracacao;Terminal;Município;UF;SGUF;Região Geográfica;Região Hidrográfica;Instalação Portuária em Rio;Nº da Capitania;Nº do IMO
#
# Linha 2: 1447857;BRRIG;RIG0048;BERÇO 8 (65 a 70);Rio Grande;-52.075555,-32.042499;;Rio Grande;Porto Organizado;17/04/2024 10:00:00;17/04/2024 06:30:00;19/04/2024 12:25:00;;;2024;abr;Marinha;Cabotagem;0;1;Cais comercial do Porto Novo;Rio Grande;Rio Grande do Sul;RS;Sul;;Não;;
#
# Linha 3: 1428966;BRRIG;RIG0048;BERÇO 8 (65 a 70);Rio Grande;-52.075555,-32.042499;;Rio Grande;Porto Organizado;26/02/2024 14:35:00;26/02/2024 11:30:00;28/02/2024 16:30:00;;;2024;fev;Marinha;Cabotagem;0;1;Cais comercial do Porto Novo;Rio Grande;Rio Grande do Sul;RS;Sul;;Não;;
#
# Linha 4: 1501997;BRMCZ;MCZ0004;Berço 4;Maceió;-35.726388,-9.683056000000001;;Maceió;Porto Organizado;25/10/2024 17:00:00;25/10/2024 15:00:00;28/10/2024 06:00:00;;;2024;out;Marinha;Cabotagem;0;1;Cais do AA-03;Maceió;Alagoas;AL;Nordeste;;Não;;
#
# Linha 5: 1466554;BRIBB;IBB0002;Berço 2;Imbituba;-48.65416700000001,-28.231389;;Imbituba;Porto Organizado;06/06/2024 14:30:00;06/06/2024 09:00:00;14/07/2024 19:10:00;;;2024;jul;Marinha;Apoio Marítimo;0;1;Cais Público;Imbituba;Santa Catarina;SC;Sul;;Não;;

# %%
df2 = pd.read_csv(file2, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106818 entries, 0 to 106817
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     106818 non-null  int64
#  1   CDTUP                           106818 non-null  object
#  2   IDBerco                         106722 non-null  object
#  3   Berço                           106721 non-null  object
#  4   Porto Atracação                 106722 non-null  object
#  5   Coordenadas                     106722 non-null  object
#  6   Apelido Instalação Portuária    31951 non-null   object
#  7   Complexo Portuário              106818 non-null  object
#  8   Tipo da Autoridade Portuária    106818 non-null  object
#  9   Data Atracação                  106722 non-null  object
#  10  Data Chegada                    106722 non-null  object
#  11  Data Desatracação               106818 non-null  object
#  12  Data Início Operação            98807 non-null   object
#  13  Data Término Operação           98808 non-null   object
#  14  Ano                             106818 non-null  int64
#  15  Mes                             106818 non-null  object
#  16  Tipo de Operação                106722 non-null  object
#  17  Tipo de Navegação da Atracação  106722 non-null  object
#  18  Nacionalidade do Armador        106722 non-null  float64
#  19  FlagMCOperacaoAtracacao         106818 non-null  int64
#  20  Terminal                        106721 non-null  object
#  21  Município                       106721 non-null  object
#  22  UF                              106721 non-null  object
#  23  SGUF                            106721 non-null  object
#  24  Região Geográfica               106721 non-null  object
#  25  Região Hidrográfica             53107 non-null   object
#  26  Instalação Portuária em Rio     106818 non-null  object
#  27  Nº da Capitania                 68833 non-null   object
#  28  Nº do IMO                       54050 non-null   float64
# dtypes: float64(2), int64(3), object(24)
# memory usage: 23.6+ MB

# %%
csv_files = [file1, file2]
ANTAQ_Int = pd.DataFrame()
for file in csv_files:
    df = pd.read_csv(file, sep=';', encoding='utf-8', low_memory=False)
    ANTAQ_Int = pd.concat([ANTAQ_Int, df], ignore_index=True)

ANTAQ_Int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200726 entries, 0 to 200725
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     200726 non-null  int64
#  1   CDTUP                           200726 non-null  object
#  2   IDBerco                         200506 non-null  object
#  3   Berço                           200505 non-null  object
#  4   Porto Atracação                 200506 non-null  object
#  5   Coordenadas                     200506 non-null  object
#  6   Apelido Instalação Portuária    62304 non-null   object
#  7   Complexo Portuário              200726 non-null  object
#  8   Tipo da Autoridade Portuária    200726 non-null  object
#  9   Data Atracação                  200506 non-null  object
#  10  Data Chegada                    200506 non-null  object
#  11  Data Desatracação               200726 non-null  object
#  12  Data Início Operação            187748 non-null  object
#  13  Data Término Operação           187769 non-null  object
#  14  Ano                             200726 non-null  int64
#  15  Mes                             200726 non-null  object
#  16  Tipo de Operação                200506 non-null  object
#  17  Tipo de Navegação da Atracação  200506 non-null  object
#  18  Nacionalidade do Armador        200506 non-null  float64
#  19  FlagMCOperacaoAtracacao         200726 non-null  int64
#  20  Terminal                        200505 non-null  object
#  21  Município                       200505 non-null  object
#  22  UF                              200505 non-null  object
#  23  SGUF                            200505 non-null  object
#  24  Região Geográfica               200505 non-null  object
#  25  Região Hidrográfica             102522 non-null  object
#  26  Instalação Portuária em Rio     200726 non-null  object
#  27  Nº da Capitania                 127767 non-null  object
#  28  Nº do IMO                       102099 non-null  float64
# dtypes: float64(2), int64(3), object(24)
# memory usage: 44.4+ MB

# %%
df.head()
# Out:
#    IDAtracacao  CDTUP  IDBerco              Berço Porto Atracação  \
# 0      1447857  BRRIG  RIG0048  BERÇO 8 (65 a 70)      Rio Grande
# 1      1428966  BRRIG  RIG0048  BERÇO 8 (65 a 70)      Rio Grande
# 2      1501997  BRMCZ  MCZ0004            Berço 4          Maceió
# 3      1466554  BRIBB  IBB0002            Berço 2        Imbituba
# 4      1504567  BRREC  RECA-04            RECA-04          Recife
#
#                      Coordenadas Apelido Instalação Portuária  \
# 0          -52.075555,-32.042499                          NaN
# 1          -52.075555,-32.042499                          NaN
# 2  -35.726388,-9.683056000000001                          NaN
# 3  -48.65416700000001,-28.231389                          NaN
# 4  -34.868332,-8.053888000000001          Arrecife dos Navios
#
#   Complexo Portuário Tipo da Autoridade Portuária       Data Atracação  ...  \
# 0         Rio Grande             Porto Organizado  17/04/2024 10:00:00  ...
# 1         Rio Grande             Porto Organizado  26/02/2024 14:35:00  ...
# 2             Maceió             Porto Organizado  25/10/2024 17:00:00  ...
# 3           Imbituba             Porto Organizado  06/06/2024 14:30:00  ...
# 4     Suape - Recife             Porto Organizado  24/10/2024 11:20:00  ...
#
#   FlagMCOperacaoAtracacao                      Terminal   Município  \
# 0                       1  Cais comercial do Porto Novo  Rio Grande
# 1                       1  Cais comercial do Porto Novo  Rio Grande
# 2                       1                 Cais do AA-03      Maceió
# 3                       1                  Cais Público    Imbituba
# 4                       1                  Cais Público      Recife
#
#                   UF  SGUF Região Geográfica Região Hidrográfica  \
# 0  Rio Grande do Sul    RS               Sul                 NaN
# 1  Rio Grande do Sul    RS               Sul                 NaN
# 2            Alagoas    AL          Nordeste                 NaN
# 3     Santa Catarina    SC               Sul                 NaN
# 4         Pernambuco    PE          Nordeste                 NaN
#
#   Instalação Portuária em Rio  Nº da Capitania  Nº do IMO
# 0                         Não              NaN        NaN
# 1                         Não              NaN        NaN
# 2                         Não              NaN        NaN
# 3                         Não              NaN        NaN
# 4                         Não              NaN        NaN
#
# [5 rows x 29 columns]

# %%
ANTAQ_Int.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco              Berço  \
# 0      1383028    BRBEL      BEL0004                  4
# 1      1330420  BRSC013  BRSC0130001             Cais 1
# 2      1371953    BRBEL      BEL0004                  4
# 3      1330416  BRSC013  BRSC0130001             Cais 1
# 4      1335677    BRRIG      RIG0047  BERÇO 7 (56 a 65)
#
#                    Porto Atracação            Coordenadas  \
# 0                            Belém   -48.497777,-1.445278
# 1  Barra do Rio Terminal Portuário      -48.6721,-26.8833
# 2                            Belém   -48.497777,-1.445278
# 3  Barra do Rio Terminal Portuário      -48.6721,-26.8833
# 4                       Rio Grande  -52.075555,-32.042499
#
#   Apelido Instalação Portuária     Complexo Portuário  \
# 0                          NaN  Vila do Conde - Belém
# 1                          NaN                 Itajaí
# 2                          NaN  Vila do Conde - Belém
# 3                          NaN                 Itajaí
# 4                          NaN             Rio Grande
#
#   Tipo da Autoridade Portuária       Data Atracação  ...  \
# 0             Porto Organizado  06/10/2023 15:50:00  ...
# 1          Terminal Autorizado  14/04/2023 14:35:00  ...
# 2             Porto Organizado  05/08/2023 13:55:00  ...
# 3          Terminal Autorizado  07/04/2023 09:25:00  ...
# 4             Porto Organizado  05/04/2023 10:40:00  ...
#
#   FlagMCOperacaoAtracacao                         Terminal   Município  \
# 0                       1           Cais Público 1 - Belém       Belém
# 1                       1  Barra do Rio Terminal Portuário      Itajaí
# 2                       1           Cais Público 1 - Belém       Belém
# 3                       1  Barra do Rio Terminal Portuário      Itajaí
# 4                       1     Cais comercial do Porto Novo  Rio Grande
#
#                   UF  SGUF Região Geográfica   Região Hidrográfica  \
# 0               Pará    PA             Norte    Tocantins-Araguaia
# 1     Santa Catarina    SC               Sul         Atlântico Sul
# 2               Pará    PA             Norte    Tocantins-Araguaia
# 3     Santa Catarina    SC               Sul         Atlântico Sul
# 4  Rio Grande do Sul    RS               Sul                   NaN
#
#   Instalação Portuária em Rio  Nº da Capitania  Nº do IMO
# 0                         Sim              NaN        NaN
# 1                         Sim              NaN        NaN
# 2                         Sim              NaN        NaN
# 3                         Sim              NaN        NaN
# 4                         Não              NaN        NaN
#
# [5 rows x 29 columns]

# %%
ANTAQ_Int.tail(5)
# Out:
#         IDAtracacao    CDTUP      IDBerco    Berço  \
# 200721      1541672  BRAM088  BRAM0885001  Berço 1
# 200722      1541678  BRAM088  BRAM0885001  Berço 1
# 200723      1541680  BRAM088  BRAM0885001  Berço 1
# 200724      1541679  BRAM088  BRAM0885001  Berço 1
# 200725      1541681  BRAM088  BRAM0885001  Berço 1
#
#                               Porto Atracação        Coordenadas  \
# 200721  Terminal Distribuidora Equador Manaus  -59.9598,-3.14456
# 200722  Terminal Distribuidora Equador Manaus  -59.9598,-3.14456
# 200723  Terminal Distribuidora Equador Manaus  -59.9598,-3.14456
# 200724  Terminal Distribuidora Equador Manaus  -59.9598,-3.14456
# 200725  Terminal Distribuidora Equador Manaus  -59.9598,-3.14456
#
#        Apelido Instalação Portuária Complexo Portuário  \
# 200721                          NaN             Manaus
# 200722                          NaN             Manaus
# 200723                          NaN             Manaus
# 200724                          NaN             Manaus
# 200725                          NaN             Manaus
#
#        Tipo da Autoridade Portuária       Data Atracação  ...  \
# 200721          Terminal Autorizado  24/12/2024 10:00:00  ...
# 200722          Terminal Autorizado  28/12/2024 01:00:00  ...
# 200723          Terminal Autorizado  30/12/2024 22:00:00  ...
# 200724          Terminal Autorizado  30/12/2024 17:00:00  ...
# 200725          Terminal Autorizado  31/12/2024 04:30:00  ...
#
#        FlagMCOperacaoAtracacao                               Terminal  \
# 200721                       1  Terminal Distribuidora Equador Manaus
# 200722                       1  Terminal Distribuidora Equador Manaus
# 200723                       1  Terminal Distribuidora Equador Manaus
# 200724                       1  Terminal Distribuidora Equador Manaus
# 200725                       1  Terminal Distribuidora Equador Manaus
#
#        Município        UF  SGUF Região Geográfica Região Hidrográfica  \
# 200721    Manaus  Amazonas    AM             Norte           Amazônica
# 200722    Manaus  Amazonas    AM             Norte           Amazônica
# 200723    Manaus  Amazonas    AM             Norte           Amazônica
# 200724    Manaus  Amazonas    AM             Norte           Amazônica
# 200725    Manaus  Amazonas    AM             Norte           Amazônica
#
#        Instalação Portuária em Rio  Nº da Capitania  Nº do IMO
# 200721                         Sim       0011467428        NaN
# 200722                         Sim       0011467428        NaN
# 200723                         Sim       0011467428        NaN
# 200724                         Sim       0011467428        NaN
# 200725                         Sim       0011467428        NaN
#
# [5 rows x 29 columns]

# %%
colunas_interesse = ['IDAtracacao', 'IDBerco', 'Data Atracação', 'Data Chegada',
                     'Data Desatracação', 'Data Início Operação', 'Data Término Operação']

# %%
ANTAQ = ANTAQ_Int.dropna(subset=colunas_interesse)
ANTAQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187731 entries, 0 to 200725
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     187731 non-null  int64
#  1   CDTUP                           187731 non-null  object
#  2   IDBerco                         187731 non-null  object
#  3   Berço                           187731 non-null  object
#  4   Porto Atracação                 187731 non-null  object
#  5   Coordenadas                     187731 non-null  object
#  6   Apelido Instalação Portuária    59108 non-null   object
#  7   Complexo Portuário              187731 non-null  object
#  8   Tipo da Autoridade Portuária    187731 non-null  object
#  9   Data Atracação                  187731 non-null  object
#  10  Data Chegada                    187731 non-null  object
#  11  Data Desatracação               187731 non-null  object
#  12  Data Início Operação            187731 non-null  object
#  13  Data Término Operação           187731 non-null  object
#  14  Ano                             187731 non-null  int64
#  15  Mes                             187731 non-null  object
#  16  Tipo de Operação                187731 non-null  object
#  17  Tipo de Navegação da Atracação  187731 non-null  object
#  18  Nacionalidade do Armador        187731 non-null  float64
#  19  FlagMCOperacaoAtracacao         187731 non-null  int64
#  20  Terminal                        187731 non-null  object
#  21  Município                       187731 non-null  object
#  22  UF                              187731 non-null  object
#  23  SGUF                            187731 non-null  object
#  24  Região Geográfica               187731 non-null  object
#  25  Região Hidrográfica             99564 non-null   object
#  26  Instalação Portuária em Rio     187731 non-null  object
#  27  Nº da Capitania                 118254 non-null  object
#  28  Nº do IMO                       95303 non-null   float64
# dtypes: float64(2), int64(3), object(24)
# memory usage: 43.0+ MB

# %%
ANTAQ['Data Chegada'] = pd.to_datetime(ANTAQ['Data Chegada'], format='%d/%m/%Y %H:%M:%S')
ANTAQ['Data Atracação'] = pd.to_datetime(ANTAQ['Data Atracação'], format='%d/%m/%Y %H:%M:%S')
ANTAQ['Data Início Operação'] = pd.to_datetime(ANTAQ['Data Início Operação'], format='%d/%m/%Y %H:%M:%S')
ANTAQ['Data Término Operação'] = pd.to_datetime(ANTAQ['Data Término Operação'], format='%d/%m/%Y %H:%M:%S')
ANTAQ['Data Desatracação'] = pd.to_datetime(ANTAQ['Data Desatracação'], format='%d/%m/%Y %H:%M:%S')
# Out:
# <ipython-input-83-772c824c77ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Data Chegada'] = pd.to_datetime(ANTAQ['Data Chegada'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-83-772c824c77ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Data Atracação'] = pd.to_datetime(ANTAQ['Data Atracação'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-83-772c824c77ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Data Início Operação'] = pd.to_datetime(ANTAQ['Data Início Operação'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-83-772c824c77ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Data Término Operação'] = pd.to_datetime(ANTAQ['Data Término Operação'], format='%d/%m/%Y %H:%M:%S')
# <ipython-input-83-772c824c77ee>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Data Desatracação'] = pd.to_datetime(ANTAQ['Data Desatracação'], format='%d/%m/%Y %H:%M:%S')

# %%
ANTAQ['Tempo_espera_chegada'] = (ANTAQ['Data Atracação'] - ANTAQ['Data Chegada']).dt.total_seconds() / 3600
ANTAQ['Tempo_espera_inicial'] = (ANTAQ['Data Início Operação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600
ANTAQ['Tempo_operacao'] = (ANTAQ['Data Término Operação'] - ANTAQ['Data Início Operação']).dt.total_seconds() / 3600
ANTAQ['Tempo_espera_final'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Término Operação']).dt.total_seconds() / 3600
ANTAQ['Tempo_ocupacao'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600
# Out:
# <ipython-input-84-77637d53eca3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_espera_chegada'] = (ANTAQ['Data Atracação'] - ANTAQ['Data Chegada']).dt.total_seconds() / 3600
# <ipython-input-84-77637d53eca3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_espera_inicial'] = (ANTAQ['Data Início Operação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600
# <ipython-input-84-77637d53eca3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_operacao'] = (ANTAQ['Data Término Operação'] - ANTAQ['Data Início Operação']).dt.total_seconds() / 3600
# <ipython-input-84-77637d53eca3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_espera_final'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Término Operação']).dt.total_seconds() / 3600
# <ipython-input-84-77637d53eca3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_ocupacao'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600

# %%
ANTAQ['Tempo_espera_chegada'] = (ANTAQ['Data Atracação'] - ANTAQ['Data Chegada']).dt.total_seconds() / 3600
ANTAQ['Tempo_espera_inicial'] = (ANTAQ['Data Início Operação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600
ANTAQ['Tempo_operacao'] = (ANTAQ['Data Término Operação'] - ANTAQ['Data Início Operação']).dt.total_seconds() / 3600
ANTAQ['Tempo_espera_final'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Término Operação']).dt.total_seconds() / 3600
ANTAQ['Tempo_ocupacao'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600
# Out:
# <ipython-input-85-77637d53eca3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_espera_chegada'] = (ANTAQ['Data Atracação'] - ANTAQ['Data Chegada']).dt.total_seconds() / 3600
# <ipython-input-85-77637d53eca3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_espera_inicial'] = (ANTAQ['Data Início Operação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600
# <ipython-input-85-77637d53eca3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_operacao'] = (ANTAQ['Data Término Operação'] - ANTAQ['Data Início Operação']).dt.total_seconds() / 3600
# <ipython-input-85-77637d53eca3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_espera_final'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Término Operação']).dt.total_seconds() / 3600
# <ipython-input-85-77637d53eca3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ANTAQ['Tempo_ocupacao'] = (ANTAQ['Data Desatracação'] - ANTAQ['Data Atracação']).dt.total_seconds() / 3600

# %%
ANTAQ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187731 entries, 0 to 200725
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     187731 non-null  int64
#  1   CDTUP                           187731 non-null  object
#  2   IDBerco                         187731 non-null  object
#  3   Berço                           187731 non-null  object
#  4   Porto Atracação                 187731 non-null  object
#  5   Coordenadas                     187731 non-null  object
#  6   Apelido Instalação Portuária    59108 non-null   object
#  7   Complexo Portuário              187731 non-null  object
#  8   Tipo da Autoridade Portuária    187731 non-null  object
#  9   Data Atracação                  187731 non-null  datetime64[ns]
#  10  Data Chegada                    187731 non-null  datetime64[ns]
#  11  Data Desatracação               187731 non-null  datetime64[ns]
#  12  Data Início Operação            187731 non-null  datetime64[ns]
#  13  Data Término Operação           187731 non-null  datetime64[ns]
#  14  Ano                             187731 non-null  int64
#  15  Mes                             187731 non-null  object
#  16  Tipo de Operação                187731 non-null  object
#  17  Tipo de Navegação da Atracação  187731 non-null  object
#  18  Nacionalidade do Armador        187731 non-null  float64
#  19  FlagMCOperacaoAtracacao         187731 non-null  int64
#  20  Terminal                        187731 non-null  object
#  21  Município                       187731 non-null  object
#  22  UF                              187731 non-null  object
#  23  SGUF                            187731 non-null  object
#  24  Região Geográfica               187731 non-null  object
#  25  Região Hidrográfica             99564 non-null   object
#  26  Instalação Portuária em Rio     187731 non-null  object
#  27  Nº da Capitania                 118254 non-null  object
#  28  Nº do IMO                       95303 non-null   float64
#  29  Tempo_espera_chegada            187731 non-null  float64
#  30  Tempo_espera_inicial            187731 non-null  float64
#  31  Tempo_operacao                  187731 non-null  float64
#  32  Tempo_espera_final              187731 non-null  float64
#  33  Tempo_ocupacao                  187731 non-null  float64
# dtypes: datetime64[ns](5), float64(7), int64(3), object(19)
# memory usage: 50.1+ MB

# %%
duplicados = ANTAQ.duplicated(subset=['IDAtracacao'], keep=False)
if duplicados.any():
    print("Existem valores duplicados.")
    print(ANTAQ[duplicados])
else:
    print("Coluna com valores unicos.")
# Out:
# Coluna com valores unicos.

# %%
coluna = 'Complexo Portuário'
CP = ANTAQ[coluna].value_counts().sort_index()
print(f"Total de operações por {coluna}:")
print(CP)
# Out:
# Total de operações por Complexo Portuário:
# Complexo Portuário
# Almeirim                                    8
# Angra dos Reis                           1190
# Aracajú                                   837
# Aratu - Salvador                         3735
# Areia Branca                             3920
# Barra do Riacho                           911
# Cabedelo (Instalação Isolada)             203
# Coari (Instalação Isolada)                958
# Corumbá                                  4619
# Forno                                      84
# Ilhéus                                    365
# Imbituba                                  682
# Itaguaí                                  2061
# Itaituba                                11453
# Itajaí                                   1505
# Itaqui                                   3978
# LDC Pederneiras (Instalação Isolada)     1462
# Macapá                                   1218
# Maceió                                    504
# Manaus                                  21846
# Natal                                     494
# Não Classificado                         4270
# Paranaguá - Antonina                     5415
# Pecém - Fortaleza                        2223
# Porto Alegre                             4595
# Porto Velho                             11558
# Rio Grande                               7434
# Rio de Janeiro -  Niterói                8671
# Santarém                                10639
# Santos                                  12374
# Suape - Recife                           4149
# São Francisco do Sul                     2442
# São João da Barra                       16451
# São Sebastião                            1621
# São Simão                                1551
# Tomé Açu                                   38
# Vila do Conde - Belém                   26750
# Vitória                                  4591
# Vitória do Xingu                           34
# Óbidos                                    892
# Name: count, dtype: int64

# %%
porto = 'Santos'
navegacao = 'Longo Curso'
filtro =  ANTAQ[(ANTAQ['Complexo Portuário'] == porto) &
                (ANTAQ['Tipo de Navegação da Atracação'] == navegacao)]
tabela = filtro.groupby('Berço').agg({'Berço': 'count'}).rename(columns={'Berço': 'Total'})
print(tabela)
# Out:
#          Total
# Berço
# AGEO 01     72
# AGEO SP     56
# AL 01       35
# AL 02       85
# AL 03      210
# ...        ...
# TIP 2      169
# TIP 3      226
# TIP 4      103
# TUF1       152
# VALONGO    237
#
# [65 rows x 1 columns]

# %%
filtro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10055 entries, 9 to 200621
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDAtracacao                     10055 non-null  int64
#  1   CDTUP                           10055 non-null  object
#  2   IDBerco                         10055 non-null  object
#  3   Berço                           10055 non-null  object
#  4   Porto Atracação                 10055 non-null  object
#  5   Coordenadas                     10055 non-null  object
#  6   Apelido Instalação Portuária    1084 non-null   object
#  7   Complexo Portuário              10055 non-null  object
#  8   Tipo da Autoridade Portuária    10055 non-null  object
#  9   Data Atracação                  10055 non-null  datetime64[ns]
#  10  Data Chegada                    10055 non-null  datetime64[ns]
#  11  Data Desatracação               10055 non-null  datetime64[ns]
#  12  Data Início Operação            10055 non-null  datetime64[ns]
#  13  Data Término Operação           10055 non-null  datetime64[ns]
#  14  Ano                             10055 non-null  int64
#  15  Mes                             10055 non-null  object
#  16  Tipo de Operação                10055 non-null  object
#  17  Tipo de Navegação da Atracação  10055 non-null  object
#  18  Nacionalidade do Armador        10055 non-null  float64
#  19  FlagMCOperacaoAtracacao         10055 non-null  int64
#  20  Terminal                        10055 non-null  object
#  21  Município                       10055 non-null  object
#  22  UF                              10055 non-null  object
#  23  SGUF                            10055 non-null  object
#  24  Região Geográfica               10055 non-null  object
#  25  Região Hidrográfica             0 non-null      object
#  26  Instalação Portuária em Rio     10055 non-null  object
#  27  Nº da Capitania                 95 non-null     object
#  28  Nº do IMO                       10050 non-null  float64
#  29  Tempo_espera_chegada            10055 non-null  float64
#  30  Tempo_espera_inicial            10055 non-null  float64
#  31  Tempo_operacao                  10055 non-null  float64
#  32  Tempo_espera_final              10055 non-null  float64
#  33  Tempo_ocupacao                  10055 non-null  float64
# dtypes: datetime64[ns](5), float64(7), int64(3), object(19)
# memory usage: 2.7+ MB

# %%
colunas_interesse1 = ['IDAtracacao','CDTUP','Berço','Porto Atracação', 'Complexo Portuário','Tipo de Navegação da Atracação',
                      'Data Chegada','Data Atracação','Data Início Operação','Data Término Operação','Data Desatracação',
                      'Tempo_espera_chegada', 'Tempo_espera_inicial','Tempo_operacao', 'Tempo_espera_final', 'Tempo_ocupacao']
ANTAQ[colunas_interesse1].to_csv(caminho_out + 'Atracacao_final3.csv', index=False, decimal='.')

# %%
drive.mount('/content/drive')
arquivo = '/content/drive/My Drive/Data/Atracacao_final3.csv'
with open(arquivo, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Linha 1: IDAtracacao,CDTUP,Berço,Porto Atracação,Complexo Portuário,Tipo de Navegação da Atracação,Data Chegada,Data Atracação,Data Início Operação,Data Término Operação,Data Desatracação,Tempo_espera_chegada,Tempo_espera_inicial,Tempo_operacao,Tempo_espera_final,Tempo_ocupacao
#
# Linha 2: 1383028,BRBEL,4,Belém,Vila do Conde - Belém,Cabotagem,2023-10-06 12:00:00,2023-10-06 15:50:00,2023-10-06 16:00:00,2023-10-08 11:00:00,2023-10-08 12:00:00,3.8333333333333335,0.16666666666666666,43.0,1.0,44.166666666666664
#
# Linha 3: 1371953,BRBEL,4,Belém,Vila do Conde - Belém,Longo Curso,2023-08-05 11:00:00,2023-08-05 13:55:00,2023-08-05 15:00:00,2023-08-09 17:00:00,2023-08-10 05:30:00,2.9166666666666665,1.0833333333333333,98.0,12.5,111.58333333333333
#
# Linha 4: 1375257,BRBEL,4,Belém,Vila do Conde - Belém,Longo Curso,2023-09-04 07:00:00,2023-09-04 07:50:00,2023-09-04 09:00:00,2023-09-08 17:00:00,2023-09-08 22:00:00,0.8333333333333334,1.1666666666666667,104.0,5.0,110.16666666666667
#
# Linha 5: 1398404,BRSSZ,OUTEIRINHOS 1,Santos,Santos,Longo Curso,2023-11-05 11:00:00,2023-11-05 11:50:00,2023-11-05 11:50:00,2023-11-06 17:25:00,2023-11-06 17:25:00,0.8333333333333334,0.0,29.583333333333332,0.0,29.583333333333332

# %%
df = pd.read_csv(arquivo, low_memory=False, sep=',', encoding='UTF-8')
df.head()
# Out:
#    IDAtracacao  CDTUP          Berço Porto Atracação     Complexo Portuário  \
# 0      1383028  BRBEL              4           Belém  Vila do Conde - Belém
# 1      1371953  BRBEL              4           Belém  Vila do Conde - Belém
# 2      1375257  BRBEL              4           Belém  Vila do Conde - Belém
# 3      1398404  BRSSZ  OUTEIRINHOS 1          Santos                 Santos
# 4      1408077  BRSSZ  OUTEIRINHOS 1          Santos                 Santos
#
#   Tipo de Navegação da Atracação         Data Chegada       Data Atracação  \
# 0                      Cabotagem  2023-10-06 12:00:00  2023-10-06 15:50:00
# 1                    Longo Curso  2023-08-05 11:00:00  2023-08-05 13:55:00
# 2                    Longo Curso  2023-09-04 07:00:00  2023-09-04 07:50:00
# 3                    Longo Curso  2023-11-05 11:00:00  2023-11-05 11:50:00
# 4                      Cabotagem  2023-12-15 05:45:00  2023-12-15 08:00:00
#
#   Data Início Operação Data Término Operação    Data Desatracação  \
# 0  2023-10-06 16:00:00   2023-10-08 11:00:00  2023-10-08 12:00:00
# 1  2023-08-05 15:00:00   2023-08-09 17:00:00  2023-08-10 05:30:00
# 2  2023-09-04 09:00:00   2023-09-08 17:00:00  2023-09-08 22:00:00
# 3  2023-11-05 11:50:00   2023-11-06 17:25:00  2023-11-06 17:25:00
# 4  2023-12-15 08:00:00   2023-12-17 08:50:00  2023-12-17 08:50:00
#
#    Tempo_espera_chegada  Tempo_espera_inicial  Tempo_operacao  \
# 0              3.833333              0.166667       43.000000
# 1              2.916667              1.083333       98.000000
# 2              0.833333              1.166667      104.000000
# 3              0.833333              0.000000       29.583333
# 4              2.250000              0.000000       48.833333
#
#    Tempo_espera_final  Tempo_ocupacao
# 0                 1.0       44.166667
# 1                12.5      111.583333
# 2                 5.0      110.166667
# 3                 0.0       29.583333
# 4                 0.0       48.833333

# %%
df = pd.read_csv(arquivo, sep=',', quotechar='"', encoding='utf-8')

# %%
import pandas as pd
colunas_datahora = [
    'Data Chegada',
    'Data Atracação',
    'Data Início Operação',
    'Data Término Operação',
    'Data Desatracação'
]

for col in colunas_datahora:
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%d %H:%M:%S', errors='coerce')
    df[f'{col}_Data'] = df[col].dt.date
    df[f'{col}_Hora'] = df[col].dt.time

# %%
df.columns
# Out:
# Index(['IDAtracacao', 'CDTUP', 'Berço', 'Porto Atracação',
#        'Complexo Portuário', 'Tipo de Navegação da Atracação', 'Data Chegada',
#        'Data Atracação', 'Data Início Operação', 'Data Término Operação',
#        'Data Desatracação', 'Tempo_espera_chegada', 'Tempo_espera_inicial',
#        'Tempo_operacao', 'Tempo_espera_final', 'Tempo_ocupacao',
#        'Data Chegada_Data', 'Data Chegada_Hora', 'Data Atracação_Data',
#        'Data Atracação_Hora', 'Data Início Operação_Data',
#        'Data Início Operação_Hora', 'Data Término Operação_Data',
#        'Data Término Operação_Hora', 'Data Desatracação_Data',
#        'Data Desatracação_Hora'],
#       dtype='object')

# %%
df.to_csv('/content/drive/My Drive/Data/Atracacao_final5.csv', index=False, decimal='.')

# %%
file3 = caminho_in+'2023Carga.csv'
with open(file3, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: ﻿IDCarga;IDAtracacao;Origem;Destino;CDMercadoria;Tipo Operação da Carga;Carga Geral Acondicionamento;ConteinerEstado;Tipo Navegação;FlagAutorizacao;FlagCabotagem;FlagCabotagemMovimentacao;FlagConteinerTamanho;FlagLongoCurso;FlagMCOperacaoCarga;FlagOffshore;FlagTransporteViaInterioir;Percurso Transporte em vias Interiores;Percurso Transporte Interiores;STNaturezaCarga;STSH2;STSH4;Natureza da Carga;Sentido;TEU;QTCarga;VLPesoCargaBruta
#
# Linha 2: 32831128;1300897;n/a;n/a;9998;Abastecimento;;;Não Indentificado;S;0;0;;0;0;0;0;;;Exclusivo;Exclusivo;Exclusivo;Granel Líquido e Gasoso;Não Informado;0;0;401,63
#
# Linha 3: 32831331;1301033;BRSAS;BRSP006;2709;Cabotagem;;;Cabotagem;S;1;1;;0;1;1;0;;;Exclusivo;Exclusivo;Exclusivo;Granel Líquido e Gasoso;Desembarcados;0;0;127607,105
#
# Linha 4: 32831332;1301034;BRSP006;BRRIO;2710;Cabotagem;;;Cabotagem;S;0;1;;0;1;0;0;;;Exclusivo;Exclusivo;Exclusivo;Granel Líquido e Gasoso;Embarcados;0;0;17943,508
#
# Linha 5: 32831366;1301052;BRBEL;BRIQI;CA01;Apoio;;;Cabotagem;S;0;1;;0;1;0;0;;;Exclusivo;Compartilhado;Compartilhado;Granel Líquido e Gasoso;Embarcados;0;0;92

# %%
df2 = pd.read_csv(file3, low_memory=False, sep=';', encoding = 'UTF-8', decimal =",")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200634 entries, 0 to 2200633
# Data columns (total 27 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   IDCarga                                 int64
#  1   IDAtracacao                             int64
#  2   Origem                                  object
#  3   Destino                                 object
#  4   CDMercadoria                            object
#  5   Tipo Operação da Carga                  object
#  6   Carga Geral Acondicionamento            object
#  7   ConteinerEstado                         object
#  8   Tipo Navegação                          object
#  9   FlagAutorizacao                         object
#  10  FlagCabotagem                           float64
#  11  FlagCabotagemMovimentacao               float64
#  12  FlagConteinerTamanho                    object
#  13  FlagLongoCurso                          float64
#  14  FlagMCOperacaoCarga                     int64
#  15  FlagOffshore                            float64
#  16  FlagTransporteViaInterioir              int64
#  17  Percurso Transporte em vias Interiores  object
#  18  Percurso Transporte Interiores          object
#  19  STNaturezaCarga                         object
#  20  STSH2                                   object
#  21  STSH4                                   object
#  22  Natureza da Carga                       object
#  23  Sentido                                 object
#  24  TEU                                     float64
#  25  QTCarga                                 int64
#  26  VLPesoCargaBruta                        float64
# dtypes: float64(6), int64(5), object(16)
# memory usage: 453.3+ MB

# %%
df2.head(5)
# Out:
#     IDCarga  IDAtracacao   Origem  Destino CDMercadoria  \
# 0  32831128      1300897      NaN      NaN         9998
# 1  32831331      1301033    BRSAS  BRSP006         2709
# 2  32831332      1301034  BRSP006    BRRIO         2710
# 3  32831366      1301052    BRBEL    BRIQI         CA01
# 4  32831367      1301052    BRIQI    BRBEL         2710
#
#   Tipo Operação da Carga Carga Geral Acondicionamento ConteinerEstado  \
# 0          Abastecimento                          NaN             NaN
# 1              Cabotagem                          NaN             NaN
# 2              Cabotagem                          NaN             NaN
# 3                  Apoio                          NaN             NaN
# 4              Cabotagem                          NaN             NaN
#
#       Tipo Navegação FlagAutorizacao  ...  \
# 0  Não Indentificado               S  ...
# 1          Cabotagem               S  ...
# 2          Cabotagem               S  ...
# 3          Cabotagem               S  ...
# 4          Cabotagem               S  ...
#
#    Percurso Transporte em vias Interiores  Percurso Transporte Interiores  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN    Cabotagem em vias interiores
#
#   STNaturezaCarga          STSH2          STSH4        Natureza da Carga  \
# 0       Exclusivo      Exclusivo      Exclusivo  Granel Líquido e Gasoso
# 1       Exclusivo      Exclusivo      Exclusivo  Granel Líquido e Gasoso
# 2       Exclusivo      Exclusivo      Exclusivo  Granel Líquido e Gasoso
# 3       Exclusivo  Compartilhado  Compartilhado  Granel Líquido e Gasoso
# 4       Exclusivo  Compartilhado  Compartilhado  Granel Líquido e Gasoso
#
#          Sentido  TEU QTCarga VLPesoCargaBruta
# 0  Não Informado  0.0       0          401.630
# 1  Desembarcados  0.0       0       127607.105
# 2     Embarcados  0.0       0        17943.508
# 3     Embarcados  0.0       0           92.000
# 4  Desembarcados  0.0       0         4249.810
#
# [5 rows x 27 columns]

# %%
file4 = caminho_in+'2024Carga.csv'
with open(file3, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: ﻿IDCarga;IDAtracacao;Origem;Destino;CDMercadoria;Tipo Operação da Carga;Carga Geral Acondicionamento;ConteinerEstado;Tipo Navegação;FlagAutorizacao;FlagCabotagem;FlagCabotagemMovimentacao;FlagConteinerTamanho;FlagLongoCurso;FlagMCOperacaoCarga;FlagOffshore;FlagTransporteViaInterioir;Percurso Transporte em vias Interiores;Percurso Transporte Interiores;STNaturezaCarga;STSH2;STSH4;Natureza da Carga;Sentido;TEU;QTCarga;VLPesoCargaBruta
#
# Linha 2: 32831128;1300897;n/a;n/a;9998;Abastecimento;;;Não Indentificado;S;0;0;;0;0;0;0;;;Exclusivo;Exclusivo;Exclusivo;Granel Líquido e Gasoso;Não Informado;0;0;401,63
#
# Linha 3: 32831331;1301033;BRSAS;BRSP006;2709;Cabotagem;;;Cabotagem;S;1;1;;0;1;1;0;;;Exclusivo;Exclusivo;Exclusivo;Granel Líquido e Gasoso;Desembarcados;0;0;127607,105
#
# Linha 4: 32831332;1301034;BRSP006;BRRIO;2710;Cabotagem;;;Cabotagem;S;0;1;;0;1;0;0;;;Exclusivo;Exclusivo;Exclusivo;Granel Líquido e Gasoso;Embarcados;0;0;17943,508
#
# Linha 5: 32831366;1301052;BRBEL;BRIQI;CA01;Apoio;;;Cabotagem;S;0;1;;0;1;0;0;;;Exclusivo;Compartilhado;Compartilhado;Granel Líquido e Gasoso;Embarcados;0;0;92

# %%
csv_files = [file3, file4]
ANTAQ_Int = pd.DataFrame()
for file in csv_files:
    df = pd.read_csv(file, sep=';', encoding='utf-8', low_memory=False)
    ANTAQ_Int = pd.concat([ANTAQ_Int, df], ignore_index=True)

ANTAQ_Int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4638396 entries, 0 to 4638395
# Data columns (total 27 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   IDCarga                                 int64
#  1   IDAtracacao                             int64
#  2   Origem                                  object
#  3   Destino                                 object
#  4   CDMercadoria                            object
#  5   Tipo Operação da Carga                  object
#  6   Carga Geral Acondicionamento            object
#  7   ConteinerEstado                         object
#  8   Tipo Navegação                          object
#  9   FlagAutorizacao                         object
#  10  FlagCabotagem                           float64
#  11  FlagCabotagemMovimentacao               float64
#  12  FlagConteinerTamanho                    object
#  13  FlagLongoCurso                          float64
#  14  FlagMCOperacaoCarga                     int64
#  15  FlagOffshore                            float64
#  16  FlagTransporteViaInterioir              int64
#  17  Percurso Transporte em vias Interiores  object
#  18  Percurso Transporte Interiores          object
#  19  STNaturezaCarga                         object
#  20  STSH2                                   object
#  21  STSH4                                   object
#  22  Natureza da Carga                       object
#  23  Sentido                                 object
#  24  TEU                                     object
#  25  QTCarga                                 int64
#  26  VLPesoCargaBruta                        object
# dtypes: float64(4), int64(5), object(18)
# memory usage: 955.5+ MB

# %%
duplicados = Carga_int.duplicated(subset=['IDAtracacao'], keep=False)
if duplicados.any():
  print('Há linhas duplicadas')
else:
  print('não há linhas duplicadas')
# Out:
# Há linhas duplicadas

# %%
ANTAQ_Int.columns = ANTAQ_Int.columns.str.strip()

# %%
sentido = 'Embarcados'
navegacao = 'Longo Curso'
cargas = ['1201', '1005', '2710', '2606']
operacao = ['Exclusivo']

# %%
df3 = ANTAQ_Int[
    (ANTAQ_Int['Sentido'] == sentido) &
    (ANTAQ_Int['Tipo Navegação'] == navegacao) &
    (ANTAQ_Int['CDMercadoria'].isin(cargas)) &
    (ANTAQ_Int['STSH4'].isin(operacao))
]

# %%
df3.info()
display(df3.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23230 entries, 72 to 4628565
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IDCarga                                 23230 non-null  int64
#  1   IDAtracacao                             23230 non-null  int64
#  2   Origem                                  23230 non-null  object
#  3   Destino                                 23230 non-null  object
#  4   CDMercadoria                            23230 non-null  object
#  5   Tipo Operação da Carga                  23230 non-null  object
#  6   Carga Geral Acondicionamento            2 non-null      object
#  7   ConteinerEstado                         0 non-null      object
#  8   Tipo Navegação                          23230 non-null  object
#  9   FlagAutorizacao                         23230 non-null  object
#  10  FlagCabotagem                           23230 non-null  float64
#  11  FlagCabotagemMovimentacao               23230 non-null  float64
#  12  FlagConteinerTamanho                    0 non-null      object
#  13  FlagLongoCurso                          23230 non-null  float64
#  14  FlagMCOperacaoCarga                     23230 non-null  int64
#  15  FlagOffshore                            23230 non-null  float64
#  16  FlagTransporteViaInterioir              23230 non-null  int64
#  17  Percurso Transporte em vias Interiores  0 non-null      object
#  18  Percurso Transporte Interiores          4621 non-null   object
#  19  STNaturezaCarga                         23230 non-null  object
#  20  STSH2                                   23230 non-null  object
#  21  STSH4                                   23230 non-null  object
#  22  Natureza da Carga                       23230 non-null  object
#  23  Sentido                                 23230 non-null  object
#  24  TEU                                     23230 non-null  object
#  25  QTCarga                                 23230 non-null  int64
#  26  VLPesoCargaBruta                        23230 non-null  object
# dtypes: float64(4), int64(5), object(18)
# memory usage: 5.0+ MB
#      IDCarga  IDAtracacao Origem Destino CDMercadoria  Tipo Operação da Carga  \
# 72  32890315      1301874  BRIQI   COZZZ         1005  Longo Curso Exportação
# 73  32890316      1301874  BRIQI   COZZZ         1005  Longo Curso Exportação
# 74  32890317      1301874  BRIQI   COZZZ         1005  Longo Curso Exportação
# 75  32890318      1301875  BRIQI   KRKUV         1005  Longo Curso Exportação
# 76  32890319      1301875  BRIQI   KRKUV         1005  Longo Curso Exportação
#
#    Carga Geral Acondicionamento ConteinerEstado Tipo Navegação  \
# 72                          NaN             NaN    Longo Curso
# 73                          NaN             NaN    Longo Curso
# 74                          NaN             NaN    Longo Curso
# 75                          NaN             NaN    Longo Curso
# 76                          NaN             NaN    Longo Curso
#
#    FlagAutorizacao  ...  Percurso Transporte em vias Interiores  \
# 72               S  ...                                     NaN
# 73               S  ...                                     NaN
# 74               S  ...                                     NaN
# 75               S  ...                                     NaN
# 76               S  ...                                     NaN
#
#     Percurso Transporte Interiores STNaturezaCarga      STSH2      STSH4  \
# 72                             NaN       Exclusivo  Exclusivo  Exclusivo
# 73                             NaN       Exclusivo  Exclusivo  Exclusivo
# 74                             NaN       Exclusivo  Exclusivo  Exclusivo
# 75                             NaN       Exclusivo  Exclusivo  Exclusivo
# 76                             NaN       Exclusivo  Exclusivo  Exclusivo
#
#     Natureza da Carga     Sentido TEU QTCarga VLPesoCargaBruta
# 72      Granel Sólido  Embarcados   0       0         6462,325
# 73      Granel Sólido  Embarcados   0       0        32153,024
# 74      Granel Sólido  Embarcados   0       0        15036,471
# 75      Granel Sólido  Embarcados   0       0            12815
# 76      Granel Sólido  Embarcados   0       0          671,196
#
# [5 rows x 27 columns]

# %%
df3['VLPesoCargaBruta'] = df3['VLPesoCargaBruta'].astype(str).str.replace(',', '.', regex=False).astype(float)
# Out:
# <ipython-input-156-e23ce7baf837>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['VLPesoCargaBruta'] = df3['VLPesoCargaBruta'].astype(str).str.replace(',', '.', regex=False).astype(float)

# %%
coluna = ['IDAtracacao', 'CDMercadoria', 'Sentido', 'Natureza da Carga']
coluna_valor = 'VLPesoCargaBruta'
cargas = df3.groupby(coluna)[coluna_valor].sum().reset_index()

# %%
cargas['VLPesoCargaBruta'] = cargas['VLPesoCargaBruta'].round(2)

# %%
cargas.head(5)
# Out:
#    IDAtracacao CDMercadoria     Sentido Natureza da Carga  VLPesoCargaBruta
# 0      1301874         1005  Embarcados     Granel Sólido          53651.82
# 1      1301875         1005  Embarcados     Granel Sólido          73916.20
# 2      1303293         1005  Embarcados     Granel Sólido          46343.97
# 3      1303948         1005  Embarcados     Granel Sólido          69911.26
# 4      1304360         1005  Embarcados     Granel Sólido          66128.95

# %%
final = pd.merge(ANTAQ, cargas, left_on='IDAtracacao', right_on='IDAtracacao', how='inner')

# %%
final['VLPesoCargaBruta'] = pd.to_numeric(final['VLPesoCargaBruta'], errors='coerce')

final['VLPesoCargaBruta_formatado'] = final['VLPesoCargaBruta'].apply(
    lambda x: f'R$ {x:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.')
)

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5279 entries, 0 to 5278
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDAtracacao                     5279 non-null   int64
#  1   CDTUP                           5279 non-null   object
#  2   IDBerco                         5279 non-null   object
#  3   Berço                           5279 non-null   object
#  4   Porto Atracação                 5279 non-null   object
#  5   Coordenadas                     5279 non-null   object
#  6   Apelido Instalação Portuária    822 non-null    object
#  7   Complexo Portuário              5279 non-null   object
#  8   Tipo da Autoridade Portuária    5279 non-null   object
#  9   Data Atracação                  5279 non-null   datetime64[ns]
#  10  Data Chegada                    5279 non-null   datetime64[ns]
#  11  Data Desatracação               5279 non-null   datetime64[ns]
#  12  Data Início Operação            5279 non-null   datetime64[ns]
#  13  Data Término Operação           5279 non-null   datetime64[ns]
#  14  Ano                             5279 non-null   int64
#  15  Mes                             5279 non-null   object
#  16  Tipo de Operação                5279 non-null   object
#  17  Tipo de Navegação da Atracação  5279 non-null   object
#  18  Nacionalidade do Armador        5279 non-null   float64
#  19  FlagMCOperacaoAtracacao         5279 non-null   int64
#  20  Terminal                        5279 non-null   object
#  21  Município                       5279 non-null   object
#  22  UF                              5279 non-null   object
#  23  SGUF                            5279 non-null   object
#  24  Região Geográfica               5279 non-null   object
#  25  Região Hidrográfica             1428 non-null   object
#  26  Instalação Portuária em Rio     5279 non-null   object
#  27  Nº da Capitania                 138 non-null    object
#  28  Nº do IMO                       5270 non-null   float64
#  29  Tempo_espera_chegada            5279 non-null   float64
#  30  Tempo_espera_inicial            5279 non-null   float64
#  31  Tempo_operacao                  5279 non-null   float64
#  32  Tempo_espera_final              5279 non-null   float64
#  33  Tempo_ocupacao                  5279 non-null   float64
#  34  CDMercadoria                    5279 non-null   object
#  35  Sentido                         5279 non-null   object
#  36  Natureza da Carga               5279 non-null   object
#  37  VLPesoCargaBruta                5279 non-null   float64
#  38  VLPesoCargaBruta_formatado      5279 non-null   object
# dtypes: datetime64[ns](5), float64(8), int64(3), object(23)
# memory usage: 1.6+ MB

# %%
final[['VLPesoCargaBruta', 'VLPesoCargaBruta_formatado']].head()
# Out:
#    VLPesoCargaBruta VLPesoCargaBruta_formatado
# 0          37387.53               R$ 37.387,53
# 1          53651.82               R$ 53.651,82
# 2          73916.20               R$ 73.916,20
# 3          48791.33               R$ 48.791,33
# 4          71500.00               R$ 71.500,00

# %%
final.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco      Berço  \
# 0      1400881  BRSP006  BRSP0060004         P4
# 1      1301874    BRIQI      IQI0103  BERÇO 103
# 2      1301875    BRIQI      IQI0103  BERÇO 103
# 3      1311897    BRSSZ      SSZ0748     ARM 38
# 4      1376295    BRIQI      IQI0103  BERÇO 103
#
#                                      Porto Atracação            Coordenadas  \
# 0  Terminal Aquaviário de São Sebastião (Almirant...      -45.3861,-23.8039
# 1                                             Itaqui   -44.368611,-2.578333
# 2                                             Itaqui   -44.368611,-2.578333
# 3                                             Santos  -46.301939,-23.966053
# 4                                             Itaqui   -44.368611,-2.578333
#
#   Apelido Instalação Portuária Complexo Portuário  \
# 0                        TEBAR      São Sebastião
# 1                          NaN             Itaqui
# 2                          NaN             Itaqui
# 3                          NaN             Santos
# 4                          NaN             Itaqui
#
#   Tipo da Autoridade Portuária      Data Atracação  ... Tempo_espera_chegada  \
# 0          Terminal Autorizado 2023-11-05 18:48:00  ...           189.800000
# 1             Porto Organizado 2022-12-30 08:44:00  ...           296.716667
# 2             Porto Organizado 2023-01-02 11:54:00  ...           309.400000
# 3             Porto Organizado 2023-01-24 05:40:00  ...           348.666667
# 4             Porto Organizado 2023-09-11 04:36:00  ...           508.800000
#
#   Tempo_espera_inicial Tempo_operacao Tempo_espera_final  Tempo_ocupacao  \
# 0             3.500000      55.700000           6.583333       65.783333
# 1             0.883333      67.883333           4.933333       73.700000
# 2             0.250000      53.100000           7.433333       60.783333
# 3             3.166667     125.300000           4.533333      133.000000
# 4             0.433333      54.466667           4.666667       59.566667
#
#   CDMercadoria     Sentido        Natureza da Carga  VLPesoCargaBruta  \
# 0         2710  Embarcados  Granel Líquido e Gasoso          37387.53
# 1         1005  Embarcados            Granel Sólido          53651.82
# 2         1005  Embarcados            Granel Sólido          73916.20
# 3         1005  Embarcados            Granel Sólido          48791.33
# 4         1005  Embarcados            Granel Sólido          71500.00
#
#    VLPesoCargaBruta_formatado
# 0                R$ 37.387,53
# 1                R$ 53.651,82
# 2                R$ 73.916,20
# 3                R$ 48.791,33
# 4                R$ 71.500,00
#
# [5 rows x 39 columns]

# %%
final.mean(numeric_only=True)
# Out:
# IDAtracacao                 1.410583e+06
# Ano                         2.023471e+03
# Nacionalidade do Armador    1.888805e+00
# FlagMCOperacaoAtracacao     1.000000e+00
# Nº do IMO                   9.631116e+06
# Tempo_espera_chegada        2.986993e+02
# Tempo_espera_inicial        4.510816e+00
# Tempo_operacao              6.522880e+01
# Tempo_espera_final          6.565590e+00
# Tempo_ocupacao              7.630520e+01
# VLPesoCargaBruta            5.833381e+04
# dtype: float64

# %%
colunas_desejadas = ['Tempo_espera_chegada', 'Tempo_espera_inicial',
                     'Tempo_operacao', 'Tempo_espera_final',
                     'Tempo_ocupacao', 'VLPesoCargaBruta']

media_selecionada = final[colunas_desejadas].mean(numeric_only=True)
pd.options.display.float_format = '{:.6f}'.format
print(media_selecionada)
# Out:
# Tempo_espera_chegada     298.699264
# Tempo_espera_inicial       4.510816
# Tempo_operacao            65.228796
# Tempo_espera_final         6.565590
# Tempo_ocupacao            76.305203
# VLPesoCargaBruta       58333.810403
# dtype: float64

# %%
import matplotlib as plt
import seaborn as sns
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})

# %%
colunas_tempo_formatar = ['Tempo_espera_chegada', 'Tempo_espera_inicial',
                          'Tempo_operacao', 'Tempo_espera_final', 'Tempo_ocupacao']

for col in colunas_tempo_formatar:
    final[col + '_formatado'] = final[col].apply(
        lambda x: f"{x:,.2f}".replace(",", "X").replace(".", ",").replace("X", ".")
    )

# %%
final.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco      Berço  \
# 0      1400881  BRSP006  BRSP0060004         P4
# 1      1301874    BRIQI      IQI0103  BERÇO 103
# 2      1301875    BRIQI      IQI0103  BERÇO 103
# 3      1311897    BRSSZ      SSZ0748     ARM 38
# 4      1376295    BRIQI      IQI0103  BERÇO 103
#
#                                      Porto Atracação            Coordenadas  \
# 0  Terminal Aquaviário de São Sebastião (Almirant...      -45.3861,-23.8039
# 1                                             Itaqui   -44.368611,-2.578333
# 2                                             Itaqui   -44.368611,-2.578333
# 3                                             Santos  -46.301939,-23.966053
# 4                                             Itaqui   -44.368611,-2.578333
#
#   Apelido Instalação Portuária Complexo Portuário  \
# 0                        TEBAR      São Sebastião
# 1                          NaN             Itaqui
# 2                          NaN             Itaqui
# 3                          NaN             Santos
# 4                          NaN             Itaqui
#
#   Tipo da Autoridade Portuária      Data Atracação  ... CDMercadoria  \
# 0          Terminal Autorizado 2023-11-05 18:48:00  ...         2710
# 1             Porto Organizado 2022-12-30 08:44:00  ...         1005
# 2             Porto Organizado 2023-01-02 11:54:00  ...         1005
# 3             Porto Organizado 2023-01-24 05:40:00  ...         1005
# 4             Porto Organizado 2023-09-11 04:36:00  ...         1005
#
#       Sentido        Natureza da Carga VLPesoCargaBruta  \
# 0  Embarcados  Granel Líquido e Gasoso     37387.530000
# 1  Embarcados            Granel Sólido     53651.820000
# 2  Embarcados            Granel Sólido     73916.200000
# 3  Embarcados            Granel Sólido     48791.330000
# 4  Embarcados            Granel Sólido     71500.000000
#
#    VLPesoCargaBruta_formatado Tempo_espera_chegada_formatado  \
# 0                R$ 37.387,53                         189,80
# 1                R$ 53.651,82                         296,72
# 2                R$ 73.916,20                         309,40
# 3                R$ 48.791,33                         348,67
# 4                R$ 71.500,00                         508,80
#
#   Tempo_espera_inicial_formatado Tempo_operacao_formatado  \
# 0                           3,50                    55,70
# 1                           0,88                    67,88
# 2                           0,25                    53,10
# 3                           3,17                   125,30
# 4                           0,43                    54,47
#
#    Tempo_espera_final_formatado  Tempo_ocupacao_formatado
# 0                          6,58                     65,78
# 1                          4,93                     73,70
# 2                          7,43                     60,78
# 3                          4,53                    133,00
# 4                          4,67                     59,57
#
# [5 rows x 44 columns]

# %%
espera_atracar = final['Tempo_espera_chegada']
espera_atracar.describe()
# Out:
# count    5279.000000
# mean      298.699264
# std      1370.888260
# min         0.000000
# 25%        37.450000
# 50%       169.816667
# 75%       359.933333
# max     87745.483333
# Name: Tempo_espera_chegada, dtype: float64

# %%
sns.histplot(espera_atracar)
# Out:
# <Axes: xlabel='Tempo_espera_chegada', ylabel='Count'>

# %%
df.to_csv('arquivo.csv', index=False, decimal='.')

# %%
final.to_csv('/content/drive/My Drive/Data/Cargas_final.csv', index=False, decimal='.')

# %%
from google.colab import drive
drive.mount('/content/drive')
caminho = '/content/drive/MyDrive/Data/Cargas_final.csv'
df = pd.read_csv(caminho)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mapeamento_produtos = {
    '1005': 'Milho',
    '1201': 'Soja',
    '2606': 'Minérios de Alumínio',
    '2710': 'Óleos de petróleo ou de minerais betuminosos, exceto óleos brutos'
}
df['Produto'] = df['CDMercadoria'].astype(str).map(mapeamento_produtos)

# %%
df.to_csv('/content/drive/MyDrive/Data/Cargas_final.csv', index=False, decimal='.')
